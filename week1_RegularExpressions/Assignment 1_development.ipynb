# %% [markdown]
# ---
#
# _You are currently looking at **version 1.0** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-text-mining/resources/d9pwm) course resource._
#
# ---

# %% [markdown]
# # Assignment 1
#
# In this assignment, you'll be working with messy medical data and using regex to extract relevant infromation from the data.
#
# Each line of the `dates.txt` file corresponds to a medical note. Each note has a date that needs to be extracted, but each date is encoded in one of many formats.
#
# The goal of this assignment is to correctly identify all of the different date variants encoded in this dataset and to properly normalize and sort the dates.
#
# Here is a list of some of the variants you might encounter in this dataset:
# * 04/20/2009; 04/20/09; 4/20/09; 4/3/09
# * Mar-20-2009; Mar 20, 2009; March 20, 2009;  Mar. 20, 2009; Mar 20 2009;
# * 20 Mar 2009; 20 March 2009; 20 Mar. 2009; 20 March, 2009
# * Mar 20th, 2009; Mar 21st, 2009; Mar 22nd, 2009
# * Feb 2009; Sep 2009; Oct 2010
# * 6/2008; 12/2009
# * 2009; 2010
#
# Once you have extracted these date patterns from the text, the next step is to sort them in ascending chronological order accoring to the following rules:
# * Assume all dates in xx/xx/xx format are mm/dd/yy
# * Assume all dates where year is encoded in only two digits are years from the 1900's (e.g. 1/5/89 is January 5th, 1989)
# * If the day is missing (e.g. 9/2009), assume it is the first day of the month (e.g. September 1, 2009).
# * If the month is missing (e.g. 2010), assume it is the first of January of that year (e.g. January 1, 2010).
#
# With these rules in mind, find the correct date in each note and return a pandas Series in chronological order of the original Series' indices.
#
# For example if the original series was this:
#
#     0    1999
#     1    2010
#     2    1978
#     3    2015
#     4    1985
#
# Your function should return this:
#
#     0    2
#     1    4
#     2    0
#     3    1
#     4    3
#
# Your score will be calculated using [Kendall's tau](https://en.wikipedia.org/wiki/Kendall_rank_correlation_coefficient), a correlation measure for ordinal data.
#
# *This function should return a Series of length 500 and dtype int.*

# %%
import pandas as pd

doc = []
with open('/Users/karenyang/Desktop/course4/dates.txt') as file:
    for line in file:
        doc.append(line)

df = pd.Series(doc)
df.head(10)
# Out:
# 0         03/25/93 Total time of visit (in minutes):\n
# 1                       6/18/85 Primary Care Doctor:\n
# 2    sshe plans to move as of 7/8/71 In-Home Servic...
# 3                7 on 9/27/75 Audit C Score Current:\n
# 4    2/6/96 sleep studyPain Treatment Pain Level (N...
# 5                    .Per 7/06/79 Movement D/O note:\n
# 6    4, 5/18/78 Patient's thoughts about current su...
# 7    10/24/89 CPT Code: 90801 - Psychiatric Diagnos...
# 8                         3/7/86 SOS-10 Total Score:\n
# 9             (4/10/71)Score-1Audit C Score Current:\n
# dtype: object

# %%
def date_sorter():
    
    # Your code here
    
    return # Your answer here

# %%
len(df)
# Out:
# 500

# %%
for line in df:
    print(line)
# Out:
# 03/25/93 Total time of visit (in minutes):
#
# 6/18/85 Primary Care Doctor:
#
# sshe plans to move as of 7/8/71 In-Home Services: None
#
# 7 on 9/27/75 Audit C Score Current:
#
# 2/6/96 sleep studyPain Treatment Pain Level (Numeric Scale): 7
#
# .Per 7/06/79 Movement D/O note:
#
# 4, 5/18/78 Patient's thoughts about current substance abuse:
#
# 10/24/89 CPT Code: 90801 - Psychiatric Diagnosis Interview
#
# 3/7/86 SOS-10 Total Score:
#
# (4/10/71)Score-1Audit C Score Current:
#
# (5/11/85) Crt-1.96, BUN-26; AST/ALT-16/22; WBC_12.6Activities of Daily Living (ADL) Bathing: Independent
#
# 4/09/75 SOS-10 Total Score:
#
# 8/01/98 Communication with referring physician?: Done
#
# 1/26/72 Communication with referring physician?: Not Done
#
# 5/24/1990 CPT Code: 90792: With medical services
#
# 1/25/2011 CPT Code: 90792: With medical services
#
# 4/12/82 Total time of visit (in minutes):
#
# 1; 10/13/1976 Audit C Score, Highest/Date:
#
# 4, 4/24/98 Relevant Drug History:
#
# ...

# %%
# index position of date errors
list_errors = [265,271,235,245,256,281,283,285,333,459,460,461,465,467,468,479,487,488,490,298,313,321,274,21]

# %%
import re

# %%
df[[21]] = re.sub(r'210/21/79', '10/21/79', df[21])
df[21]
# Out:
# '10/21/79 SOS-10 Total Score:\n'

# %%
df[[235]] = re.sub(r'pOct 2015', 'Oct 2015', df[235])
df[235]
# Out:
# 'Oct 2015 - Admitted to Gray Clinic for depression, alcohol intox/dependence and SI.  Discharged to MH Partial Hospital---on trazadone 50 mg QHS, Ativan 0.5 mg BID, Wellbutrin 150 mg BID, Seroquel 50 mg QHS and Zoloft 100 mg.  It is unclear if patient attended Memorial partial hospital program.  By report she had refills of trazadone and sertraline via PCP (see HPI).Hx of Outpatient Treatment: Yes\n'

# %%
df[[245]] = re.sub(r'lNovember 1990', '01 November 1990', df[245])
df[245]
# Out:
# '01 November 1990 - NPCCHx of Outpatient Treatment: Yes\n'

# %%
df[[256]] = re.sub(r'IAug 1988', 'Aug 1988', df[256])
df[256]
# Out:
# 'Aug 1988: Symmes Hospital s/p SA OD with ASA\n'

# %%
df[[265]] = re.sub(r'/', '', df[265])
df[265]
# Out:
# '.  Pt reports ho difficulty with EtOH and opioids. EtOH: 1st use at age 10, regular use beginning in high school, more problematic at age 25 when started losing things.  Drinking 12 beersday over past year since returning to State College from Alaska.  Unsure of heaviest use period.  ho frequent blackouts.  Has passed out and woken up in variety of places.  ho withdrawal symptoms, 1st detox at age 25, no ho withdrawal seizure, no DTs.  opioids: 1st use at age 21 (perocet).  Began using daily at age 25, at worst was using 8 to 10 percocets per day (depending on dose).  Detox in April 1989, was using perioidically since back in State College, but has primarily been drinking.  Last use 3 mths ago.  no ho suboxone or methadone.  No ho accidental OD.  No ho heroin use.  No ho IVDU.  tobacco: 1 ppd since age 16, some interest in quitting, not right now.  Ho quitting for a week.\n'

# %%
df[[271]] = re.sub(r'708-810-7787 ', '', df[271])
df[271]
# Out:
# '.Spoke to sister Naomi Ely who reports he has been doing much better since he went to Dysart Clinic (he was drinking for a month leading up to this, his ammonia was high, and physicians were worried about early).  She feels his cognition is back to baseline, "100% better".  She says he has been successful in abstaining from substances as far as she knows, thinks a schedule is useful to him, doctor\'s appts etc.  Notes that he returned from LA in August 2008, gets bouts of "exhaustion" even in sobriety.  She denies ever witnessing any periods of manic behavior from patient.  Their father has dementia that started at age 84.  Notes patient is living with uncle in Black River Falls (uncle is 89), lived with sister 3 months who also takes care of her own father in Talladega.  She knows he is working on getting social security, subsidizing housing.  Stable situation with patient\'s girlfriend Nutt.Suicidal Behavior Hx of Suicidal Behavior: No\n'

# %%
df[[274]] = re.sub(r'7HH, April 1985', 'April 1985', df[274])
df[274]
# Out:
# 'April 1985 Hx of Outpatient Treatment:\n'

# %%
df[[281]] = re.sub(r'yAug 2004', 'Aug 2004', df[281])
df[281]
# Out:
# 'Aug 2004 - Dr. Tom Ngo at TMC; dx GAD; patient stopped after two visits re: "I was scared if this meant I was sick and really needed this", despite success in controlling anxiety-related symptoms of nausea after just one treatment visit.Psychiatric Review of Systems DEPRESSION: Has the patient had periods of time lasting two weeks or longer in which, most of the day on most days, they felt little interest or pleasure in doing things, or they had to push themselves to do things: No\n'

# %%
df[[284]] = re.sub(r'- Jan 1987', 'Jan 1987', df[284])
df[284]
# Out:
# '.  Alvarado Medical Center Jan 1987 : worsening psychosis and mania (impulsivity of going to Pompeii, grandiosity in wanting to send script to famous playwright, increased painting activity, maxed out credit card, decreased sleep) Hx of Outpatient Treatment: Yes\n'

# %%
df[[285]] = re.sub(r'sSep 1983 GSW', 'Sep 1983 GSW', df[285])
df[285]
# Out:
# 'Sep 1983 GSW to face (L-TMJ region), ? gang related, with L-CN VII injury and ? TBI, requiring plastic surgical reconstructionActivities of Daily Living (ADL) Bathing: Independent\n'

# %%
df[[333]] = re.sub(r'sNovember 1997', 'November 1997', df[333])
df[333]
# Out:
# 'November 1997 - suicidal ideation - HHR\n'

# %%
df[[460]] = re.sub(r'1 Ex-smoker : quit 2012', 'Ex-smoker : quit 2012 ', df[460])
df[460]
# Out:
# 'Ex-smoker : quit 2012 \n'

# %%
df[[461]] = re.sub(r'. Age 16, 1991,', '1991', df[461])
df[461]
# Out:
# '1991 frontal impact. out for two weeks from sports.\n'

# %%
df[[462]] = re.sub(r'sLexapro (1988-now): Good response (anxiety)', '1988', df[462])
df[462]
# Out:
# 'sLexapro (1988-now): Good response (anxiety)\n'

# %%
df[[465]] = re.sub(r'.Age, 19, 1976, ', '1976 ', df[465])
df[465]
# Out:
# '1976 playing football, frontal impact. out for two weeks from sports.\n'

# %%
df[[466]] = re.sub(r's1981 ', '1981 ', df[466])
df[466]
# Out:
# '1981  Swedish-American Hospital\n'

# %%
df[[467]] = re.sub(r'aS/P ', '', df[467])
df[467]
# Out:
# 'suicide attempt 2011 Hx of Outpatient Treatment: Yes\n'

# %%
df[[479]] = re.sub(r'(1993)', '1993', df[479])
df[479]
# Out:
# 'sIn KEP Psychiatryfor therapy and medications since 1996 Prior medication trials (including efficacy, reasons discontinued):\n'

# %%
df[[487]] = re.sub(r'appendectomy s/p delivery 1992', '1992', df[487])
df[487]
# Out:
# '1992 Prior relevant labs:\n'

# %%
df[[488]] = re.sub(r': s/p nephrectomy 1977', '1977', df[488])
df[488]
# Out:
# 'tProblems renal cell cancer 1977\n'

# %%
df[[490]] = re.sub(r'Lab: B12 969 2007', '2007 ', df[490])
df[490]
# Out:
# '2007 \n'

# %%
# Write expressions for group of same data format

# %%
expression1 = r'\d{,2}[/-]\d{,2}[/-]\d{2,4}'

# %%
# test cases for expression1
line0 = "09/14/2000 CPT Code: 90792: With medical services"
line1 = "sOP WPM - Dr. Romo-psychopharm since 11/22/75"
line2 = "4-13-82 Other Child Mental Health Outcomes Scales Used:"
line3 = "Dilantin (PHENYTOIN) 100 MG CAPSULE Take 2 Capsule(s) PO HS; No Change (Taking Differently), \
Comments: decreased from 290 daily to 260 mg daily due to elevated phenytoin level from 8/9/97"
line4 = "PET Scan (DPSH 5/04/74): 1)"

# %%
result0 = re.findall(expression1, line0)
result1 = re.findall(expression1, line1)
result2 = re.findall(expression1, line2)
result3 = re.findall(expression1, line3)
result4 = re.findall(expression1, line4)

# %%
print(result0)
print(result1)
print(result2)
print(result3)
print(result4)
# Out:
# ['09/14/2000']
# ['11/22/75']
# ['4-13-82']
# ['8/9/97']
# ['5/04/74']

# %%
expression1 = r'\d{,2}[/-]\d{,2}[/-]\d{2,4}'

list1 = []
for line in df[0:125]:
    
    result1 = re.findall(expression1, line)
    if result1 != []:
        list1.append(result1[0])
print(list1)
# Out:
# ['03/25/93', '6/18/85', '7/8/71', '9/27/75', '2/6/96', '7/06/79', '5/18/78', '10/24/89', '3/7/86', '4/10/71', '5/11/85', '4/09/75', '8/01/98', '1/26/72', '5/24/1990', '1/25/2011', '4/12/82', '10/13/1976', '4/24/98', '5/21/77', '7/21/98', '10/21/79', '3/03/90', '2/11/76', '07/25/1984', '4-13-82', '9/22/89', '9/02/76', '9/12/71', '10/24/86', '03/31/1985', '7/20/72', '4/12/87', '06/20/91', '5/12/2012', '3/15/83', '2/14/73', '5/24/88', '7/27/1986', '1-14-81', '7-29-75', '6/24/87', '8/14/94', '4/13/2002', '8/16/82', '2/15/1998', '7/15/91', '06/12/94', '9/17/84', '2/28/75', '11/22/75', '5/24/91', '6/13/92', '7/11/71', '12/26/86', '10/11/1987', '3/14/95', '12/01/73', '12/5/2010', '08/20/1982', '7/24/95', '8/06/83', '02/22/92', '6/28/87', '07/29/1994', '08/11/78', '10/29/91', '7/6/91', '1/21/87', '11/3/1985', '7/04/82', '4-13-89', '7/11/77', '4/12/74', '09/19/81', '9/6/79', '12/5/87', '01/05/1999', '4/22/80', '10/04/98', '6/29/81', '8/04/78', '7/07/1974', '09/14/2000', '5/18/71', '8/09/1981'
# ...

# %%
len(df[0:125])
# Out:
# 125

# %%
from dateutil.parser import parse
lista = []

for item in list1:
    a = str(parse(item , dayfirst=False))
    lista.append(a)
    
print(lista)
# Out:
# ['1993-03-25 00:00:00', '1985-06-18 00:00:00', '1971-07-08 00:00:00', '1975-09-27 00:00:00', '1996-02-06 00:00:00', '1979-07-06 00:00:00', '1978-05-18 00:00:00', '1989-10-24 00:00:00', '1986-03-07 00:00:00', '1971-04-10 00:00:00', '1985-05-11 00:00:00', '1975-04-09 00:00:00', '1998-08-01 00:00:00', '1972-01-26 00:00:00', '1990-05-24 00:00:00', '2011-01-25 00:00:00', '1982-04-12 00:00:00', '1976-10-13 00:00:00', '1998-04-24 00:00:00', '1977-05-21 00:00:00', '1998-07-21 00:00:00', '1979-10-21 00:00:00', '1990-03-03 00:00:00', '1976-02-11 00:00:00', '1984-07-25 00:00:00', '1982-04-13 00:00:00', '1989-09-22 00:00:00', '1976-09-02 00:00:00', '1971-09-12 00:00:00', '1986-10-24 00:00:00', '1985-03-31 00:00:00', '1972-07-20 00:00:00', '1987-04-12 00:00:00', '1991-06-20 00:00:00', '2012-05-12 00:00:00', '1983-03-15 00:00:00', '1973-02-14 00:00:00', '1988-05-24 00:00:00', '1986-07-27 00:00:00', '1981-01-14 00:00:00', '1975-07-29 00:00:00', '1987-06-24 00:00:00', '1994-08-14 00:00:00', '2002-04
# ...

# %%
len(lista)
# Out:
# 125

# %%
expression2 = r'(?:\d{0,2} )?(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z.,\s]* (?:\d{ ,2}, )?\d{4}'
expression3 = r'(?:\d{0,2} )?(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z.,]* \d{0,2}[,.\s]*\d{2,4}'

# %%
# test cases for expression2 and expression3
line4 = ".On 21 Oct 1983 patient was discharged from Scroder Hospital after EIGHT DAY ADMISSION"
line5 = "11 February 1985 CPT Code: 90801 - Psychiatric Diagnosis Interview"
line6 = "19 Oct 2016 Communication with referring physician?: Done"
line7 = "20 March, 2009"
line8 = "20 Mar. 2009"
line9 = "06 May 1972 SOS-10 Total Score:"
line10 = "24 Jan 2001"
line11 = "May, 2011"
line12 = "August 12 2004"

# %%
result4 = re.findall(expression2, line4)
result5 = re.findall(expression3, line5)
result6 = re.findall(expression3, line6)
result7 = re.findall(expression2, line7)
result8 = re.findall(expression2, line8)
result9 = re.findall(expression2, line9)
result10 = re.findall(expression2, line10)
result11 = re.findall(expression3, line11)
result12 = re.findall(expression3, line12)

# %%
print(result4)
print(result5)
print(result6)
print(result7)
print(result8)
print(result9)
print(result10)
print(result11)
print(result12)
# Out:
# ['21 Oct 1983']
# ['11 February 1985']
# ['19 Oct 2016']
# ['20 March, 2009']
# ['20 Mar. 2009']
# ['06 May 1972']
# ['24 Jan 2001']
# ['May, 2011']
# ['August 12 2004']

# %%
expression2 = r'(?:\d{0,2} )?(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z.,\s]* (?:\d{ ,2}, )?\d{4}'
expression3 = r'(?:\d{0,2} )?(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z.,]* \d{0,2}[,.\s]*\d{2,4}'

list2 = []
for line in df[125:228]:
    
    result2 = re.findall(expression2, line)
    if result2 != []:
        list2.append(result2[0])
    else:
        result2 = re.findall(expression3, line)
        list2.append(result2[0])
        
print(list2)
# Out:
# ['24 Jan 2001', '10 Sep 2004', '26 May 1982', '28 June 2002', '06 May 1972', '25 Oct 1987', '14 Oct 1996', '30 Nov 2007', '28 June 1994', '14 Jan 1981', '10 Oct 1985', '11 February 1985', '10 Feb 1983', '05 Feb 1992', '21 Oct 2012', '14 Feb 1995', '30 May 2016', '22 Jan 1996', '14 Oct 1992', '06 Oct 2003', '18 Oct 1999', '11 Nov 2004', '30 May 2001', '02 Feb 1978', '09 Sep 1989', '12 March 1980', '22 June 1990', '28 Sep 2015', '13 Jan 1972', '06 Mar 1974', '10 Oct 1974', '26 May 1974', '10 Feb 1990', '23 Aug 2000', '26 May 2001', '21 Oct 2007', '19 Oct 2016', '05 Mar 1974', '29 Jan 1994', '21 Oct 1978', '18 August 1975', '11 Nov 1996', '01 Oct 1979', '13 Oct 1986', '21 Oct 1995', '24 Jan 2011', '04 Oct 1972', '23 Aug 1993', '18 Oct 2006', '04 Dec 1988', '21 Oct 1983', '26 May 2010', '18 Jan 1990', '15 Jun 1985', '10 Dec 1982', '09 Dec 1988', '18 August 1995', '13 June 1974', '26 May 2008', '11 Nov 2002', '17 Aug 1985', '13 Oct 2016', '14 Jan 2008', '12 March 2004', '21 Oct 1977', '10
# ...

# %%
len(df[125:228])
# Out:
# 103

# %%
len(list2)
# Out:
# 103

# %%
from dateutil.parser import parse
listb = []

for item in list2:
    b = str(parse(item, dayfirst=False))
    listb.append(b)
    
print(listb)
# Out:
# ['2001-01-24 00:00:00', '2004-09-10 00:00:00', '1982-05-26 00:00:00', '2002-06-28 00:00:00', '1972-05-06 00:00:00', '1987-10-25 00:00:00', '1996-10-14 00:00:00', '2007-11-30 00:00:00', '1994-06-28 00:00:00', '1981-01-14 00:00:00', '1985-10-10 00:00:00', '1985-02-11 00:00:00', '1983-02-10 00:00:00', '1992-02-05 00:00:00', '2012-10-21 00:00:00', '1995-02-14 00:00:00', '2016-05-30 00:00:00', '1996-01-22 00:00:00', '1992-10-14 00:00:00', '2003-10-06 00:00:00', '1999-10-18 00:00:00', '2004-11-11 00:00:00', '2001-05-30 00:00:00', '1978-02-02 00:00:00', '1989-09-09 00:00:00', '1980-03-12 00:00:00', '1990-06-22 00:00:00', '2015-09-28 00:00:00', '1972-01-13 00:00:00', '1974-03-06 00:00:00', '1974-10-10 00:00:00', '1974-05-26 00:00:00', '1990-02-10 00:00:00', '2000-08-23 00:00:00', '2001-05-26 00:00:00', '2007-10-21 00:00:00', '2016-10-19 00:00:00', '1974-03-05 00:00:00', '1994-01-29 00:00:00', '1978-10-21 00:00:00', '1975-08-18 00:00:00', '1996-11-11 00:00:00', '1979-10-01 00:00:00', '1986-10
# ...

# %%
len(listb)
# Out:
# 103

# %%
expression4 = r'(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z.,]* (?:\d{ ,2}, )?\d{4}'

# %%
# test case for expression4
line13 = ".Nov 2007- Evaluation and treatment at CH ED/APS for acute alcohol and medication OD,"

# %%
result13 = re.findall(expression4, line13)

# %%
print(result13)
# Out:
# ['Nov 2007']

# %%
expression4 = r'(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z.,]* (?:\d{ ,2}, )?\d{4}'
              
list4 = []
for line in df[228:321]:
    
    result4 = re.findall(expression4, line)
    if result4 != []:
        list4.append(result4[0])
    # correct misspellings for 'Decemeber 1978' and 'Janaury 1993'
list4[-8] = "December 1978"
list4[-23] = 'January 1993'
    
print(list4)
# Out:
# ['September 1985', 'June 2011', 'May 1986', 'May 2016', 'July 1977', 'July, 1990', 'Jul 2003', 'Oct 2015', 'May 1995', 'February 1976', 'January 1995', 'Feb 1978', 'May, 2011', 'May 2004', 'Nov 2010', 'Sep 2012', 'January, 2013', 'November 1990', 'July 1981', 'May 1983', 'July 1995', 'April 1993', 'May 2005', 'December 1998', 'Jan 2007', 'Feb 2016', 'August 1979', 'Oct 2014', 'Aug 1988', 'Sep 2015', 'Apr 1976', 'Nov 1979', 'February 2000', 'Oct 1986', 'Jun 2002', 'September 1981', 'June 2007', 'April 1989', 'September 1999', 'Oct 1980', 'Dec 2009', 'July 1992', 'May, 2006', 'August 2008', 'Feb 1993', 'February, 2010', 'April 1985', 'September 1984', 'April 1986', 'Apr 2007', 'September 1974', 'Sep 2013', 'July 1985', 'Aug 2004', 'May 2012', 'Feb 1977', 'Jan 1987', 'Sep 1983', 'January 2013', 'Mar 2010', 'August 2009', 'Sep 2007', 'December 2011', 'Jan 2004', 'November 1995', 'September 2008', 'February 1983', 'March 1983', 'Aug 1979', 'Jan 2009', 'January 1993', 'March 1974', 'Januar
# ...

# %%
len(df[228:321])
# Out:
# 93

# %%
len(list4)
# Out:
# 93

# %%
list44 = []
for item in list4:
    x = "01 " + item
    list44.append(x)

print(list44)
# Out:
# ['01 September 1985', '01 June 2011', '01 May 1986', '01 May 2016', '01 July 1977', '01 July, 1990', '01 Jul 2003', '01 Oct 2015', '01 May 1995', '01 February 1976', '01 January 1995', '01 Feb 1978', '01 May, 2011', '01 May 2004', '01 Nov 2010', '01 Sep 2012', '01 January, 2013', '01 November 1990', '01 July 1981', '01 May 1983', '01 July 1995', '01 April 1993', '01 May 2005', '01 December 1998', '01 Jan 2007', '01 Feb 2016', '01 August 1979', '01 Oct 2014', '01 Aug 1988', '01 Sep 2015', '01 Apr 1976', '01 Nov 1979', '01 February 2000', '01 Oct 1986', '01 Jun 2002', '01 September 1981', '01 June 2007', '01 April 1989', '01 September 1999', '01 Oct 1980', '01 Dec 2009', '01 July 1992', '01 May, 2006', '01 August 2008', '01 Feb 1993', '01 February, 2010', '01 April 1985', '01 September 1984', '01 April 1986', '01 Apr 2007', '01 September 1974', '01 Sep 2013', '01 July 1985', '01 Aug 2004', '01 May 2012', '01 Feb 1977', '01 Jan 1987', '01 Sep 1983', '01 January 2013', '01 Mar 2010', '01
# ...

# %%
len(list44)
# Out:
# 93

# %%
listc = []

for item in list44:
    c = str(parse(item, dayfirst=False))
    print(c)
    listc.append(c)
# Out:
# 1985-09-01 00:00:00
# 2011-06-01 00:00:00
# 1986-05-01 00:00:00
# 2016-05-01 00:00:00
# 1977-07-01 00:00:00
# 1990-07-01 00:00:00
# 2003-07-01 00:00:00
# 2015-10-01 00:00:00
# 1995-05-01 00:00:00
# 1976-02-01 00:00:00
# 1995-01-01 00:00:00
# 1978-02-01 00:00:00
# 2011-05-01 00:00:00
# 2004-05-01 00:00:00
# 2010-11-01 00:00:00
# 2012-09-01 00:00:00
# 2013-01-01 00:00:00
# 1990-11-01 00:00:00
# 1981-07-01 00:00:00
# 1983-05-01 00:00:00
# 1995-07-01 00:00:00
# 1993-04-01 00:00:00
# 2005-05-01 00:00:00
# 1998-12-01 00:00:00
# 2007-01-01 00:00:00
# 2016-02-01 00:00:00
# 1979-08-01 00:00:00
# 2014-10-01 00:00:00
# 1988-08-01 00:00:00
# 2015-09-01 00:00:00
# 1976-04-01 00:00:00
# 1979-11-01 00:00:00
# 2000-02-01 00:00:00
# 1986-10-01 00:00:00
# 2002-06-01 00:00:00
# 1981-09-01 00:00:00
# 2007-06-01 00:00:00
# 1989-04-01 00:00:00
# 1999-09-01 00:00:00
# 1980-10-01 00:00:00
# 2009-12-01 00:00:00
# 1992-07-01 00:00:00
# 2006-05-01 00:00:00
# 2008-08-01 00:00:00
# 1993-02-01 00:00:00
# ...

# %%
print(len(listc))
# Out:
# 93

# %%
expression5 = r'(?:\d{1,2})(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z.,\w]* (?:\d{ ,2}, )?\d{4}'

print(df[321])  # need to fix line 321
# Out:
# 2June, 1999 Audit C Score Current:

# %%
expression5 = r'(?:\d{1,2})(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z.,\w]* (?:\d{ ,2}, )?\d{4}'
list5 = []

result13 = re.findall(expression5, "2June, 1999")
x = result13[0][0] + ' ' + result13[0][1:] 
list5.append(x)
print(list5)
# Out:
# ['2 June, 1999']

# %%
listd = []

for item in list5:
    d = str(parse(item, dayfirst=False))
    print(d)
    listd.append(d)
# Out:
# 1999-06-02 00:00:00

# %%
expression6 = r'(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z.,]* [.,\s]?\d{4}'

# %%
# test case for expression6
line15 = "dCelexa: most helpful, came off half-way through sr yr (Feb 1994) b/c had been doing well enough to not need it"
line16 = ") Paxil (Jan 1978) : sedation"
line17 = "Hep C and HIV negative, LFTs WNL (October 1996)Problems Opioid dependence"
line18 = "sNovember 1997 - suicidal ideation - HHR"

# %%
result15 = re.findall(expression6, line15)
result16 = re.findall(expression6, line16)
result17 = re.findall(expression6, line17)
result18 = re.findall(expression6, line18)

# %%
print(result15)
print(result16)
print(result17)
print(result18)
# Out:
# ['Feb 1994']
# ['Jan 1978']
# ['October 1996']
# ['November 1997']

# %%
expression6 = r'(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z.,]* [.,\s]?\d{4}'

list6 = []

for line in df[322:345]:
    
    result6 = re.findall(expression6, line)
    if result6 != []:
        list6.append(result6[0])
print(list6)
# Out:
# ['October 1991', 'March 1973', 'October 1996', 'Jun 2007', 'October 1995', 'April 1999', 'May, 2001', 'March, 2000', 'April 1988', 'December 1993', 'June 1974', 'November 1997', 'July 1986', 'February 1973', 'March 1978', 'Dec 2007', 'Apr, 1998', 'March, 2005', 'May 1980', 'Nov 2007', 'March 1976']

# %%
len(df[322:343])
# Out:
# 21

# %%
len(list6)
# Out:
# 21

# %%
list66 = []
for item in list6:
    x = "01 " + item
    list66.append(x)

print(list66)
# Out:
# ['01 October 1991', '01 March 1973', '01 October 1996', '01 Jun 2007', '01 October 1995', '01 April 1999', '01 May, 2001', '01 March, 2000', '01 April 1988', '01 December 1993', '01 June 1974', '01 November 1997', '01 July 1986', '01 February 1973', '01 March 1978', '01 Dec 2007', '01 Apr, 1998', '01 March, 2005', '01 May 1980', '01 Nov 2007', '01 March 1976']

# %%
liste = []

for item in list66:
    e = str(parse(item, dayfirst=False))
    print(e)
    liste.append(e)
# Out:
# 1991-10-01 00:00:00
# 1973-03-01 00:00:00
# 1996-10-01 00:00:00
# 2007-06-01 00:00:00
# 1995-10-01 00:00:00
# 1999-04-01 00:00:00
# 2001-05-01 00:00:00
# 2000-03-01 00:00:00
# 1988-04-01 00:00:00
# 1993-12-01 00:00:00
# 1974-06-01 00:00:00
# 1997-11-01 00:00:00
# 1986-07-01 00:00:00
# 1973-02-01 00:00:00
# 1978-03-01 00:00:00
# 2007-12-01 00:00:00
# 1998-04-01 00:00:00
# 2005-03-01 00:00:00
# 1980-05-01 00:00:00
# 2007-11-01 00:00:00
# 1976-03-01 00:00:00

# %%
expression7 = r'\d{0,2}[/-]\d{2,4}'

# %%
# test cases for expression7
line19 = "12/2005 Family Psych History: Family History of Suicidal Behavior: None"
line20 = ".Mother died, 1/1983."
line21 = "see above.   Last cutting in 3/1995 Violent Behavior Hx of Violent Behavior: No"

# %%
result19 = re.findall(expression7, line19)
result20 = re.findall(expression7, line20)
result21 = re.findall(expression7, line21)

# %%
print(result19)
print(result20)
print(result21)
# Out:
# ['12/2005']
# ['1/1983']
# ['3/1995']

# %%
expression7 = r'\d{,2}[/-]\d{2,4}'

list7 = []

for line in df[343:455]:
    
    result7 = re.findall(expression7, line)
    if result7 != []:
        list7.append(result7[0])
print(list7)
# Out:
# ['6/1998', '6/2005', '10/1973', '9/2005', '03/1980', '12/2005', '5/1987', '5/2004', '8/1974', '3/1986', '10/1997', '3/1993', '3/1981', '9/2003', '10/1993', '1/1983', '7/1994', '12/2008', '10/1980', '8/2003', '12/1975', '11/2010', '7/1997', '7/2014', '9/2001', '8/1986', '1/1978', '9/1975', '1/2009', '5/1995', '8/1989', '11/2000', '06/1973', '2/1999', '6/2001', '12/1978', '8/2009', '7/1973', '1/2014', '09/1975', '12/2012', '5/1999', '7/1989', '7/2009', '11/1998', '3/1995', '2/2009', '08/1988', '4/2007', '5/2000', '4/2012', '10/2001', '2/1977', '8/2008', '2/1983', '5/1979', '1/1992', '11/2008', '12/2014', '4/1974', '10/1981', '10/1986', '03/1973', '12/1994', '8/1999', '10/2010', '10/1994', '01/2007', '8/2010', '03/1990', '11/2016', '4/2004', '2/1973', '7/1987', '8/2000', '8/1975', '5/1977', '3/2000', '9/1984', '4/1973', '12/1986', '4/1979', '7/2004', '11/1984', '5/2016', '12/2007', '11/1982', '06/1981', '4/2013', '4/1999', '5/2006', '10/1978', '12/1989', '2/1974', '11/1986', '4/1983', '
# ...

# %%
temp = []
for i in list7:
    x = i.split('/')
    temp.append(x)
temp
# Out:
# [['6', '1998'],
#  ['6', '2005'],
#  ['10', '1973'],
#  ['9', '2005'],
#  ['03', '1980'],
#  ['12', '2005'],
#  ['5', '1987'],
#  ['5', '2004'],
#  ['8', '1974'],
#  ['3', '1986'],
#  ['10', '1997'],
#  ['3', '1993'],
#  ['3', '1981'],
#  ['9', '2003'],
#  ['10', '1993'],
#  ['1', '1983'],
#  ['7', '1994'],
#  ['12', '2008'],
#  ['10', '1980'],
#  ['8', '2003'],
#  ['12', '1975'],
#  ['11', '2010'],
#  ['7', '1997'],
#  ['7', '2014'],
#  ['9', '2001'],
#  ['8', '1986'],
#  ['1', '1978'],
#  ['9', '1975'],
#  ['1', '2009'],
#  ['5', '1995'],
#  ['8', '1989'],
#  ['11', '2000'],
#  ['06', '1973'],
#  ['2', '1999'],
#  ['6', '2001'],
#  ['12', '1978'],
#  ['8', '2009'],
#  ['7', '1973'],
#  ['1', '2014'],
#  ['09', '1975'],
#  ['12', '2012'],
#  ['5', '1999'],
#  ['7', '1989'],
#  ['7', '2009'],
#  ['11', '1998'],
#  ['3', '1995'],
#  ['2', '2009'],
#  ['08', '1988'],
#  ['4', '2007'],
#  ['5', '2000'],
#  ['4', '2012'],
#  ['10', '2001'],
#  ['2', '1977'],
#  ['8', '2008'],
# ...

# %%
# put in format of month/day/year
list77 = []
for i in temp:
    b = i[0] + "/01/" + i[1]
    list77.append(b)
list77
# Out:
# ['6/01/1998',
#  '6/01/2005',
#  '10/01/1973',
#  '9/01/2005',
#  '03/01/1980',
#  '12/01/2005',
#  '5/01/1987',
#  '5/01/2004',
#  '8/01/1974',
#  '3/01/1986',
#  '10/01/1997',
#  '3/01/1993',
#  '3/01/1981',
#  '9/01/2003',
#  '10/01/1993',
#  '1/01/1983',
#  '7/01/1994',
#  '12/01/2008',
#  '10/01/1980',
#  '8/01/2003',
#  '12/01/1975',
#  '11/01/2010',
#  '7/01/1997',
#  '7/01/2014',
#  '9/01/2001',
#  '8/01/1986',
#  '1/01/1978',
#  '9/01/1975',
#  '1/01/2009',
#  '5/01/1995',
#  '8/01/1989',
#  '11/01/2000',
#  '06/01/1973',
#  '2/01/1999',
#  '6/01/2001',
#  '12/01/1978',
#  '8/01/2009',
#  '7/01/1973',
#  '1/01/2014',
#  '09/01/1975',
#  '12/01/2012',
#  '5/01/1999',
#  '7/01/1989',
#  '7/01/2009',
#  '11/01/1998',
#  '3/01/1995',
#  '2/01/2009',
#  '08/01/1988',
#  '4/01/2007',
#  '5/01/2000',
#  '4/01/2012',
#  '10/01/2001',
#  '2/01/1977',
#  '8/01/2008',
#  '2/01/1983',
#  '5/01/1979',
#  '1/01/1992',
#  '11/01/2008',
#  '12/01/2014',
#  '4/01/1974',
#  '10/01/1981',
# ...

# %%
listf = []

for item in list77:
    f = str(parse(item, dayfirst=False))
    listf.append(f)
    
print(listf)
# Out:
# ['1998-06-01 00:00:00', '2005-06-01 00:00:00', '1973-10-01 00:00:00', '2005-09-01 00:00:00', '1980-03-01 00:00:00', '2005-12-01 00:00:00', '1987-05-01 00:00:00', '2004-05-01 00:00:00', '1974-08-01 00:00:00', '1986-03-01 00:00:00', '1997-10-01 00:00:00', '1993-03-01 00:00:00', '1981-03-01 00:00:00', '2003-09-01 00:00:00', '1993-10-01 00:00:00', '1983-01-01 00:00:00', '1994-07-01 00:00:00', '2008-12-01 00:00:00', '1980-10-01 00:00:00', '2003-08-01 00:00:00', '1975-12-01 00:00:00', '2010-11-01 00:00:00', '1997-07-01 00:00:00', '2014-07-01 00:00:00', '2001-09-01 00:00:00', '1986-08-01 00:00:00', '1978-01-01 00:00:00', '1975-09-01 00:00:00', '2009-01-01 00:00:00', '1995-05-01 00:00:00', '1989-08-01 00:00:00', '2000-11-01 00:00:00', '1973-06-01 00:00:00', '1999-02-01 00:00:00', '2001-06-01 00:00:00', '1978-12-01 00:00:00', '2009-08-01 00:00:00', '1973-07-01 00:00:00', '2014-01-01 00:00:00', '1975-09-01 00:00:00', '2012-12-01 00:00:00', '1999-05-01 00:00:00', '1989-07-01 00:00:00', '2009-07
# ...

# %%
expression8  = r'\d{4}'

# %%
#test cases for expression8
line23 = "2008 partial thyroidectomy"
line24 = "Lab: B12 969 2007"
line25 = "eHistory of small right parietal subgaleal hematoma s/p MVA (1993)"
line26 = ".Age, 19, 1976, playing football, frontal impact. out for two weeks from sports."
line27 = "1 Ex-smoker : quit 2012"

# %%
result23 = re.findall(expression8, line23)
result24 = re.findall(expression8, line24)
result25 = re.findall(expression8, line25)
result26 = re.findall(expression8, line26)
result27 = re.findall(expression8, line27)

# %%
print(result23)
print(result24)
print(result25)
print(result26)
print(result27)
# Out:
# ['2008']
# ['2007']
# ['1993']
# ['1976']
# ['2012']

# %%
expression8  = r'\d{4}'

list8 = []

for line in df[455:]:
    
    result8 = re.findall(expression8, line)
    if result8 != []:
        list8.append(result8[0])
print(list8)
# Out:
# ['1984', '2000', '2001', '1982', '1998', '2012', '1991', '1988', '2014', '2016', '1976', '1981', '2011', '1997', '2003', '1983', '1999', '2010', '1975', '1972', '2015', '1989', '1994', '1993', '1996', '2013', '1974', '1990', '1995', '2004', '1987', '1973', '1992', '1977', '1985', '2007', '2009', '1986', '1978', '2002', '1979', '2006', '2008', '2005', '1980']

# %%
list88 = []
for item in list8:
    x = "01/01/" + item
    list88.append(x)

print(list88)
# Out:
# ['01/01/1984', '01/01/2000', '01/01/2001', '01/01/1982', '01/01/1998', '01/01/2012', '01/01/1991', '01/01/1988', '01/01/2014', '01/01/2016', '01/01/1976', '01/01/1981', '01/01/2011', '01/01/1997', '01/01/2003', '01/01/1983', '01/01/1999', '01/01/2010', '01/01/1975', '01/01/1972', '01/01/2015', '01/01/1989', '01/01/1994', '01/01/1993', '01/01/1996', '01/01/2013', '01/01/1974', '01/01/1990', '01/01/1995', '01/01/2004', '01/01/1987', '01/01/1973', '01/01/1992', '01/01/1977', '01/01/1985', '01/01/2007', '01/01/2009', '01/01/1986', '01/01/1978', '01/01/2002', '01/01/1979', '01/01/2006', '01/01/2008', '01/01/2005', '01/01/1980']

# %%
listg = []

for item in list88:
    g = str(parse(item, dayfirst=False))
    listg.append(g)
    
print(listg)
# Out:
# ['1984-01-01 00:00:00', '2000-01-01 00:00:00', '2001-01-01 00:00:00', '1982-01-01 00:00:00', '1998-01-01 00:00:00', '2012-01-01 00:00:00', '1991-01-01 00:00:00', '1988-01-01 00:00:00', '2014-01-01 00:00:00', '2016-01-01 00:00:00', '1976-01-01 00:00:00', '1981-01-01 00:00:00', '2011-01-01 00:00:00', '1997-01-01 00:00:00', '2003-01-01 00:00:00', '1983-01-01 00:00:00', '1999-01-01 00:00:00', '2010-01-01 00:00:00', '1975-01-01 00:00:00', '1972-01-01 00:00:00', '2015-01-01 00:00:00', '1989-01-01 00:00:00', '1994-01-01 00:00:00', '1993-01-01 00:00:00', '1996-01-01 00:00:00', '2013-01-01 00:00:00', '1974-01-01 00:00:00', '1990-01-01 00:00:00', '1995-01-01 00:00:00', '2004-01-01 00:00:00', '1987-01-01 00:00:00', '1973-01-01 00:00:00', '1992-01-01 00:00:00', '1977-01-01 00:00:00', '1985-01-01 00:00:00', '2007-01-01 00:00:00', '2009-01-01 00:00:00', '1986-01-01 00:00:00', '1978-01-01 00:00:00', '2002-01-01 00:00:00', '1979-01-01 00:00:00', '2006-01-01 00:00:00', '2008-01-01 00:00:00', '2005-01
# ...

# %%
final_list = lista + listb + listc + listd + liste + listf + listg

# %%
len(final_list)
# Out:
# 500

# %%
final_list
# Out:
# ['1993-03-25 00:00:00',
#  '1985-06-18 00:00:00',
#  '1971-07-08 00:00:00',
#  '1975-09-27 00:00:00',
#  '1996-02-06 00:00:00',
#  '1979-07-06 00:00:00',
#  '1978-05-18 00:00:00',
#  '1989-10-24 00:00:00',
#  '1986-03-07 00:00:00',
#  '1971-04-10 00:00:00',
#  '1985-05-11 00:00:00',
#  '1975-04-09 00:00:00',
#  '1998-08-01 00:00:00',
#  '1972-01-26 00:00:00',
#  '1990-05-24 00:00:00',
#  '2011-01-25 00:00:00',
#  '1982-04-12 00:00:00',
#  '1976-10-13 00:00:00',
#  '1998-04-24 00:00:00',
#  '1977-05-21 00:00:00',
#  '1998-07-21 00:00:00',
#  '1979-10-21 00:00:00',
#  '1990-03-03 00:00:00',
#  '1976-02-11 00:00:00',
#  '1984-07-25 00:00:00',
#  '1982-04-13 00:00:00',
#  '1989-09-22 00:00:00',
#  '1976-09-02 00:00:00',
#  '1971-09-12 00:00:00',
#  '1986-10-24 00:00:00',
#  '1985-03-31 00:00:00',
#  '1972-07-20 00:00:00',
#  '1987-04-12 00:00:00',
#  '1991-06-20 00:00:00',
#  '2012-05-12 00:00:00',
#  '1983-03-15 00:00:00',
#  '1973-02-14 00:00:00',
#  '1988-05-24 00:00:00',
# ...

# %%
second_list = []

for date in final_list:
    x = date.replace('00:00:00',"")
    second_list.append(x)
    
second_list
# Out:
# ['1993-03-25 ',
#  '1985-06-18 ',
#  '1971-07-08 ',
#  '1975-09-27 ',
#  '1996-02-06 ',
#  '1979-07-06 ',
#  '1978-05-18 ',
#  '1989-10-24 ',
#  '1986-03-07 ',
#  '1971-04-10 ',
#  '1985-05-11 ',
#  '1975-04-09 ',
#  '1998-08-01 ',
#  '1972-01-26 ',
#  '1990-05-24 ',
#  '2011-01-25 ',
#  '1982-04-12 ',
#  '1976-10-13 ',
#  '1998-04-24 ',
#  '1977-05-21 ',
#  '1998-07-21 ',
#  '1979-10-21 ',
#  '1990-03-03 ',
#  '1976-02-11 ',
#  '1984-07-25 ',
#  '1982-04-13 ',
#  '1989-09-22 ',
#  '1976-09-02 ',
#  '1971-09-12 ',
#  '1986-10-24 ',
#  '1985-03-31 ',
#  '1972-07-20 ',
#  '1987-04-12 ',
#  '1991-06-20 ',
#  '2012-05-12 ',
#  '1983-03-15 ',
#  '1973-02-14 ',
#  '1988-05-24 ',
#  '1986-07-27 ',
#  '1981-01-14 ',
#  '1975-07-29 ',
#  '1987-06-24 ',
#  '1994-08-14 ',
#  '2002-04-13 ',
#  '1982-08-16 ',
#  '1998-02-15 ',
#  '1991-07-15 ',
#  '1994-06-12 ',
#  '1984-09-17 ',
#  '1975-02-28 ',
#  '1975-11-22 ',
#  '1991-05-24 ',
#  '1992-06-13 ',
#  '1971-07-11 ',
#  '1986-12-26 ',
# ...

# %%
splitlist =[]
for date in second_list:
    b = date.replace('-', ' ')
    splitlist.append(b)
splitlist
# Out:
# ['1993 03 25 ',
#  '1985 06 18 ',
#  '1971 07 08 ',
#  '1975 09 27 ',
#  '1996 02 06 ',
#  '1979 07 06 ',
#  '1978 05 18 ',
#  '1989 10 24 ',
#  '1986 03 07 ',
#  '1971 04 10 ',
#  '1985 05 11 ',
#  '1975 04 09 ',
#  '1998 08 01 ',
#  '1972 01 26 ',
#  '1990 05 24 ',
#  '2011 01 25 ',
#  '1982 04 12 ',
#  '1976 10 13 ',
#  '1998 04 24 ',
#  '1977 05 21 ',
#  '1998 07 21 ',
#  '1979 10 21 ',
#  '1990 03 03 ',
#  '1976 02 11 ',
#  '1984 07 25 ',
#  '1982 04 13 ',
#  '1989 09 22 ',
#  '1976 09 02 ',
#  '1971 09 12 ',
#  '1986 10 24 ',
#  '1985 03 31 ',
#  '1972 07 20 ',
#  '1987 04 12 ',
#  '1991 06 20 ',
#  '2012 05 12 ',
#  '1983 03 15 ',
#  '1973 02 14 ',
#  '1988 05 24 ',
#  '1986 07 27 ',
#  '1981 01 14 ',
#  '1975 07 29 ',
#  '1987 06 24 ',
#  '1994 08 14 ',
#  '2002 04 13 ',
#  '1982 08 16 ',
#  '1998 02 15 ',
#  '1991 07 15 ',
#  '1994 06 12 ',
#  '1984 09 17 ',
#  '1975 02 28 ',
#  '1975 11 22 ',
#  '1991 05 24 ',
#  '1992 06 13 ',
#  '1971 07 11 ',
#  '1986 12 26 ',
# ...

# %%
# Make the dataframe
dataframe1 = pd.DataFrame(splitlist)
dataframe1.head()
# Out:
#              0
# 0  1993 03 25
# 1  1985 06 18
# 2  1971 07 08
# 3  1975 09 27
# 4  1996 02 06

# %%
dataframe1.columns = ['Date']
dataframe1.head()
# Out:
#           Date
# 0  1993 03 25
# 1  1985 06 18
# 2  1971 07 08
# 3  1975 09 27
# 4  1996 02 06

# %%
# Make 3 columns

dataframe1[['year','month','day']] = (dataframe1.Date.str.split().apply(lambda x: 
                                    pd.Series({'day':int(x[0]),'month':int(x[1]),'year':int(x[-1])})))

# %%
dataframe1.head()
# Out:
#           Date  year  month  day
# 0  1993 03 25   1993      3   25
# 1  1985 06 18   1985      6   18
# 2  1971 07 08   1971      7    8
# 3  1975 09 27   1975      9   27
# 4  1996 02 06   1996      2    6

# %%
# Sort columns together to maintain row order
df_final = dataframe1.sort_values(['year','month','day'])
df_final.index.names = ['Index']

# %%
df_final
# Out:
#               Date  year  month  day
# Index
# 9      1971 04 10   1971      4   10
# 84     1971 05 18   1971      5   18
# 2      1971 07 08   1971      7    8
# 53     1971 07 11   1971      7   11
# 28     1971 09 12   1971      9   12
# 474    1972 01 01   1972      1    1
# 153    1972 01 13   1972      1   13
# 13     1972 01 26   1972      1   26
# 129    1972 05 06   1972      5    6
# 98     1972 05 13   1972      5   13
# 111    1972 06 10   1972      6   10
# 225    1972 06 15   1972      6   15
# 31     1972 07 20   1972      7   20
# 171    1972 10 04   1972     10    4
# 191    1972 11 30   1972     11   30
# 486    1973 01 01   1973      1    1
# 335    1973 02 01   1973      2    1
# 415    1973 02 01   1973      2    1
# 36     1973 02 14   1973      2   14
# 323    1973 03 01   1973      3    1
# 405    1973 03 01   1973      3    1
# 422    1973 04 01   1973      4    1
# 375    1973 06 01   1973      6    1
# 380    1973 07 01   1973      7    1
# ...

# %%
df_final.index.values
# Out:
# array([  9,  84,   2,  53,  28, 474, 153,  13, 129,  98, 111, 225,  31,
#        171, 191, 486, 335, 415,  36, 323, 405, 422, 375, 380, 345,  57,
#        481, 436, 104, 299, 162, 154, 402,  95,  73, 108, 156, 332, 182,
#         82, 351, 278, 214, 155, 223, 473,  49, 317,  11, 319,  40, 418,
#        165, 370, 382,   3,  50, 363, 219, 465, 237,  23, 342, 204, 258,
#        315,  27,  93,  17, 303, 488, 283, 395, 309, 419, 123,  19, 117,
#        232,  72, 189, 318, 369, 493, 239, 148, 105, 336,   6, 200,  81,
#         65, 434, 164, 313, 378, 495, 424, 398,   5, 254, 296,  75, 167,
#         21, 259, 499, 347, 150,  78, 340, 441, 267, 361, 221, 466,  39,
#        134, 197, 355, 430,  80, 246, 444,  85, 215, 263,  74, 403, 458,
#         16,  25, 127, 454,  70,  44,  59, 103, 112, 429,  88, 179, 358,
#        470, 205, 294, 397, 137, 295,  35, 438, 247, 209,  61, 107, 285,
#        175,  99, 455,  24, 275, 421,  48, 426, 489, 136,  30, 274,  10,
# ...

# %%
last_list = df_final.index.get_values().tolist()

# %%
index_series = pd.Series(last_list)

# %%
index_series
# Out:
# 0        9
# 1       84
# 2        2
# 3       53
# 4       28
# 5      474
# 6      153
# 7       13
# 8      129
# 9       98
# 10     111
# 11     225
# 12      31
# 13     171
# 14     191
# 15     486
# 16     335
# 17     415
# 18      36
# 19     323
# 20     405
# 21     422
# 22     375
# 23     380
# 24     345
# 25      57
# 26     481
# 27     436
# 28     104
# 29     299
#       ...
# 470    220
# 471    208
# 472    243
# 473    139
# 474    320
# 475    383
# 476    244
# 477    286
# 478    480
# 479    431
# 480    279
# 481    198
# 482    381
# 483    463
# 484    366
# 485    255
# 486    439
# 487    401
# 488    475
# 489    257
# 490    152
# 491    235
# 492    464
# 493    253
# 494    231
# 495    427
# 496    141
# 497    186
# 498    161
# 499    413
# Length: 500, dtype: int64

# %%
# df_final.iloc[[100,150,300,321]]
